# %% [markdown]
# #MNIST Veri Kümesini Kullanarak Yapay Sinir Ağları İle Rakam Sınıflandırma

# %% [markdown]
# ## MNIST Veri Kümesini Yüklemek

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ## Yapay Sinir Ağı Mimarisi

# %%
from keras import models
from keras import layers

# %%
network = models.Sequential()
network.add(layers.Dense(512, activation = 'relu', input_shape = (28 * 28, )))
network.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# ## YSA Modelinin Derlenmesi

# %%
network.compile(optimizer = 'rmsprop', 
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])

# %% [markdown]
# ## Girişlerin ve Etiketlerin Hazırlanması

# %%
train_images = train_images.reshape((60000, 28* 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28* 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## YSA Modelinin Eğitilmesi

# %%
network.fit(train_images, train_labels, epochs = 5, batch_size = 128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2543 - accuracy: 0.9259
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1040 - accuracy: 0.9692
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0679 - accuracy: 0.9795
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0494 - accuracy: 0.9855
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0372 - accuracy: 0.9891

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0617 - accuracy: 0.9802

# %%
print('test_loss: ', test_loss)
# Out:
# test_loss:  0.061673060059547424

# %%
print('test_accuracy: ', test_acc)
# Out:
# test_accuracy:  0.9801999926567078
